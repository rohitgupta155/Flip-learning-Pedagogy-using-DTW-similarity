# %%
#Without cluster 1 second data
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

#data = np.loadtxt('data.txt')
data_rating =pd.read_csv(r"C:\Users\KIIT\Downloads\Minor Project\Our work\Labels_for_Beta_Alpha(0-1).csv", header=None)
data_rating=np.array(data_rating)
#print(data_rating)

Ground_trute =  pd.read_csv('GT_Label_1_20.csv', header=None)
Ground_trute=np.array(Ground_trute)

print("Without cluster")


for i in range(0, len(Ground_trute)):
    print("................",(i+1))
    actual = Ground_trute[i]
    predicted = data_rating[i]
    print(actual)
    print(predicted)
    results = confusion_matrix(actual, predicted) 
  
    print ('Confusion Matrix :')
    print(results) 
    print ('Accuracy Score :',accuracy_score(actual, predicted) )
    print ('Report : ')
    print (classification_report(actual, predicted))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7512\3366232388.py in <module>
#       7
#       8 #data = np.loadtxt('data.txt')
# ----> 9 data_rating =  pd.read_csv('All_without_cluster_1sec.csv', header=None)
#      10 data_rating=np.array(data_rating)
#      11 #print(data_rating)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'All_without_cluster_1sec.csv'

# %%
#Without cluster 2 second data
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

#data = np.loadtxt('data.txt')
data_rating =  pd.read_csv('All_without_cluster_2sec.csv', header=None)
data_rating=np.array(data_rating)
#print(data_rating)

Ground_trute =  pd.read_csv('GT_Label_1_20.csv', header=None)
Ground_trute=np.array(Ground_trute)

print("Without cluster")


for i in range(0, len(Ground_trute)):
    print("................",(i+1))
    actual = Ground_trute[i]
    predicted = data_rating[i]
    print(actual)
    print(predicted)
    results = confusion_matrix(actual, predicted) 
  
    print ('Confusion Matrix :')
    print(results) 
    print ('Accuracy Score :',accuracy_score(actual, predicted) )
    print ('Report : ')
    print (classification_report(actual, predicted))

# %%
#Without cluster 3 second data
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

#data = np.loadtxt('data.txt')
data_rating =  pd.read_csv('All_without_cluster_3sec.csv', header=None)
data_rating=np.array(data_rating)
#print(data_rating)

Ground_trute =  pd.read_csv('GT_Label_1_20.csv', header=None)
Ground_trute=np.array(Ground_trute)

print("Without cluster")


for i in range(0, len(Ground_trute)):
    print("................",(i+1))
    actual = Ground_trute[i]
    predicted = data_rating[i]
    print(actual)
    print(predicted)
    results = confusion_matrix(actual, predicted) 
  
    print ('Confusion Matrix :')
    print(results) 
    print ('Accuracy Score :',accuracy_score(actual, predicted) )
    print ('Report : ')
    print (classification_report(actual, predicted))

# %%
#With cluster_k 1 second data
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

#data = np.loadtxt('data.txt')
data_rating =  pd.read_csv('All_with_cluster_k_1sec.csv', header=None)
data_rating=np.array(data_rating)
#print(data_rating)

Ground_trute =  pd.read_csv('GT_Label_1_44.csv', header=None)
Ground_trute=np.array(Ground_trute)

print("With cluster")


for i in range(0, len(Ground_trute)):
    print("................",(i+1))
    actual = Ground_trute[i]
    predicted = data_rating[i]
    print(actual)
    print(predicted)
    results = confusion_matrix(actual, predicted) 
  
    print ('Confusion Matrix :')
    print(results) 
    print ('Accuracy Score :',accuracy_score(actual, predicted) )
    print ('Report : ')
    print (classification_report(actual, predicted))

# %%
#With cluster_k 2 second data
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

#data = np.loadtxt('data.txt')
data_rating =  pd.read_csv('All_with_cluster_k_2sec.csv', header=None)
data_rating=np.array(data_rating)
#print(data_rating)

Ground_trute =  pd.read_csv('GT_Label_1_44.csv', header=None)
Ground_trute=np.array(Ground_trute)

print("With cluster")


for i in range(0, len(Ground_trute)):
    print("................",(i+1))
    actual = Ground_trute[i]
    predicted = data_rating[i]
    print(actual)
    print(predicted)
    results = confusion_matrix(actual, predicted) 
  
    print ('Confusion Matrix :')
    print(results) 
    print ('Accuracy Score :',accuracy_score(actual, predicted) )
    print ('Report : ')
    print (classification_report(actual, predicted))

# %%
#With cluster_k 3 second data
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

#data = np.loadtxt('data.txt')
data_rating =  pd.read_csv('All_with_cluster_k_3sec.csv', header=None)
data_rating=np.array(data_rating)
#print(data_rating)

Ground_trute =  pd.read_csv('GT_Label_1_44.csv', header=None)
Ground_trute=np.array(Ground_trute)

print("With cluster")


for i in range(0, len(Ground_trute)):
    print("................",(i+1))
    actual = Ground_trute[i]
    predicted = data_rating[i]
    print(actual)
    print(predicted)
    results = confusion_matrix(actual, predicted) 
  
    print ('Confusion Matrix :')
    print(results) 
    print ('Accuracy Score :',accuracy_score(actual, predicted) )
    print ('Report : ')
    print (classification_report(actual, predicted))

# %%
#With cluster 1 second data
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

#data = np.loadtxt('data.txt')
data_rating =  pd.read_csv('All_with_cluster_B_1sec.csv', header=None)
data_rating=np.array(data_rating)
#print(data_rating)

Ground_trute =  pd.read_csv('GT_Label_1_20.csv', header=None)
Ground_trute=np.array(Ground_trute)

print("With cluster")


for i in range(0, len(Ground_trute)):
    print("................",(i+1))
    actual = Ground_trute[i]
    predicted = data_rating[i]
    print(actual)
    print(predicted)
    results = confusion_matrix(actual, predicted) 
  
    print ('Confusion Matrix :')
    print(results) 
    print ('Accuracy Score :',accuracy_score(actual, predicted) )
    print ('Report : ')
    print (classification_report(actual, predicted))

# %%
#With cluster 2 second data
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

#data = np.loadtxt('data.txt')
data_rating =  pd.read_csv('All_with_cluster_B_2sec.csv', header=None)
data_rating=np.array(data_rating)
#print(data_rating)

Ground_trute =  pd.read_csv('GT_Label_1_20.csv', header=None)
Ground_trute=np.array(Ground_trute)

print("With cluster")


for i in range(0, len(Ground_trute)):
    print("................",(i+1))
    actual = Ground_trute[i]
    predicted = data_rating[i]
    print(actual)
    print(predicted)
    results = confusion_matrix(actual, predicted) 
  
    print ('Confusion Matrix :')
    print(results) 
    print ('Accuracy Score :',accuracy_score(actual, predicted) )
    print ('Report : ')
    print (classification_report(actual, predicted))

# %%
#With cluster 3 second data
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

#data = np.loadtxt('data.txt')
data_rating =  pd.read_csv('All_with_cluster_B_3sec.csv', header=None)
data_rating=np.array(data_rating)
#print(data_rating)

Ground_trute =  pd.read_csv('GT_Label_1_20.csv', header=None)
Ground_trute=np.array(Ground_trute)

print("With cluster")


for i in range(0, len(Ground_trute)):
    print("................",(i+1))
    actual = Ground_trute[i]
    predicted = data_rating[i]
    print(actual)
    print(predicted)
    results = confusion_matrix(actual, predicted) 
  
    print ('Confusion Matrix :')
    print(results) 
    print ('Accuracy Score :',accuracy_score(actual, predicted) )
    print ('Report : ')
    print (classification_report(actual, predicted))
