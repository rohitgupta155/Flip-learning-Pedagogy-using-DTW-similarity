# %%
import pandas as pd
no_of_users=20
no_of_video=10
for i in range(no_of_users):  
        if(i%1 == 0):
            if i < 10:
                name = '%0*d' % (2,i+1)
            else:
                name = i+1
        for j in range(no_of_video):
            
            fname = "DataSet/DataSet_one_second/S"+str(name)+"_1/S"+str(name)+"_video"+str(j+1)+".csv" 
            print(fname)
            df = pd.read_csv(fname)
            df.drop(df.head(3000).index, inplace=True)
            df.drop(df.tail(3000).index, inplace=True)
            df.to_csv(fname)
# Out:
# DataSet/DataSet_one_second/S01_1/S01_video1.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8684\2682373922.py in <module>
#      12             fname = "DataSet/DataSet_one_second/S"+str(name)+"_1/S"+str(name)+"_video"+str(j+1)+".csv"
#      13             print(fname)
# ---> 14             df = pd.read_csv(fname)
#      15             df.drop(df.head(3000).index, inplace=True)
#      16             df.drop(df.tail(3000).index, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from sklearn.decomposition import PCA
import numpy as np
import pylab as pyl
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv
import pywt, numpy
import itertools 



list_f=[]
no_of_users=20
no_of_video=10

for i in range(no_of_users):   #no_of_users
        print(".............................",i)
        if(i%1 == 0 ):
            if i < 10:
                name = '%0*d' % (2,i+1)
            else:
                name = i+1
        for j in range(no_of_video):
            
            fname = "DataSet/DataSet_one_second/S"+str(name)+"_1/S"+str(name)+"_video"+str(j+1)+".csv" 
            fname = "DataSet/DataSet_one_second1/S"+str(name)+"_1/S"+str(name)+"_video"+str(j+1)+".csv" 
            print(fname)
            print(fname1)
            df1 = pd.read_csv(fname)
            df=df1['RAW']
            #print(type(df))
            x = df.values.tolist()
            list_f.append(x)
            #df.values
            print(len(x))
            n = 512
  
            # using list comprehension 
            final = [x[i * n:(i + 1) * n] for i in range((len(x) + n - 1) // n )]  
            print (len(final))
            final = final[:-1]
            np.savetxt(fname1, final, delimiter=",")

# %%
from sklearn.decomposition import PCA
import numpy as np
import pylab as pyl
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv
import pywt, numpy
import itertools 



list_f=[]
no_of_users=20
no_of_video=10

for i in range(no_of_users):   #no_of_users
        print(".............................",i)
        
        if(i%1 == 0 ):
            if i < 10:
                name = '%0*d' % (2,i+1)
            else:
                name = i+1
        for j in range(no_of_video):
            
            fname = "C:\\Users\\KIIT\\Downloads\\Flip learning pedagogy DTW\\Data\\DataSet_two_second\\S"+str(i)+"_2\\s"+format(i,'02d')+"_video"+str(j)+".csv"
            pr            df1 = pd.read_csv(fname)
            df=df1['RAW']
            #print(type(df))
            x = df.values.tolist()
            list_f.append(x)
            #df.values
            print(len(x))
            n = 1024
  
            # using list comprehension 
            final = [x[i * n:(i + 1) * n] for i in range((len(x) + n - 1) // n )]  
            print (len(final))
            final = final[:-1]
            np.savetxt(fname1, final, delimiter=",")

# %%
from sklearn.decomposition import PCA
import numpy as np
import pylab as pyl
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv
import pywt, numpy
import itertools 



list_f=[]
no_of_users=20
no_of_video=10

for i in range(no_of_users):   #no_of_users
        print(".............................",i)
       
        if(i%1 == 0 ):
            if i < 10:
                name = '%0*d' % (2,i+1)
            else:
                name = i+1
        for j in range(no_of_video):
            
            fname = "DataSet/DataSet_three_second/S"+str(name)+"_3/S"+str(name)+"_video"+str(j+1)+".csv" 
            fname = "DataSet/DataSet_three_second3/S"+str(name)+"_3/S"+str(name)+"_video"+str(j+1)+".csv" 
            print(fname)
            print(fname1)
            df1 = pd.read_csv(fname)
            df=df1['RAW']
            #print(type(df))
            x = df.values.tolist()
            list_f.append(x)
            #df.values
            print(len(x))
            n = 1536
  
            # using list comprehension 
            final = [x[i * n:(i + 1) * n] for i in range((len(x) + n - 1) // n )]  
            print (len(final))
            final = final[:-1]
            np.savetxt(fname1, final, delimiter=",")
