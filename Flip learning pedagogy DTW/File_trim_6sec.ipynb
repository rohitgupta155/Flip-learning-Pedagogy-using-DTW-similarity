# %%
from sklearn.decomposition import PCA
import numpy as np
import pylab as pyl
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv
import pywt, numpy
import itertools 



list_f=[]
no_of_users=20
no_of_video=10

for i in range(1,no_of_users+1):   #no_of_users
        print(".............................",i)
        for j in range(no_of_video):
            
            fname1 = "C:\\Users\\KIIT\\Downloads\\Flip learning pedagogy DTW\\DataSet\\DataSet_one_second\\S"+str(i)+"_1\\s"+format(i,'02d')+"_video"+str(j)+".csv"
            print(fname1)
            df = pd.read_csv(fname1)
#             df=df1['RAW']
            #print(type(df))
#             x = df.values.tolist()
#             list_f.append(x)
#             #df.values
#             print(len(x))
#             n = 1024
  
#             # using list comprehension 
#             final = [x[i * n:(i + 1) * n] for i in range((len(x) + n - 1) // n )]  
#             print (len(final))
#             final = final[:-1]
            df = df.iloc[:, :512]
            np.savetxt(fname1, df, delimiter=",")

# %%
from sklearn.decomposition import PCA
import numpy as np
import pylab as pyl
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv
import pywt, numpy
import itertools 



list_f=[]
no_of_users=20
no_of_video=10

for i in range(1,no_of_users+1):   #no_of_users
        print(".............................",i)
        for j in range(no_of_video):
            
            fname1 = "C:\\Users\\KIIT\\Downloads\\Flip learning pedagogy DTW\\DataSet\\DataSet_two_second\\S"+str(i)+"_2\\s"+format(i,'02d')+"_video"+str(j)+".csv"
            print(fname1)
            df = pd.read_csv(fname1)
#             df=df1['RAW']
            #print(type(df))
#             x = df.values.tolist()
#             list_f.append(x)
#             #df.values
#             print(len(x))
#             n = 1024
  
#             # using list comprehension 
#             final = [x[i * n:(i + 1) * n] for i in range((len(x) + n - 1) // n )]  
#             print (len(final))
#             final = final[:-1]
            df = df.iloc[:, :512]
            np.savetxt(fname1, df, delimiter=",")
# Out:
# ............................. 1
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_two_second\S1_2\s01_video0.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_two_second\S1_2\s01_video1.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_two_second\S1_2\s01_video2.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_two_second\S1_2\s01_video3.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_two_second\S1_2\s01_video4.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_two_second\S1_2\s01_video5.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_two_second\S1_2\s01_video6.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_two_second\S1_2\s01_video7.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_two_second\S1_2\s01_video8.csv
# ...

# %%
from sklearn.decomposition import PCA
import numpy as np
import pylab as pyl
import matplotlib.pyplot as plt
import pandas as pd
import os
import csv
import pywt, numpy
import itertools 



list_f=[]
no_of_users=20
no_of_video=10

for i in range(1,no_of_users+1):   #no_of_users
        print(".............................",i)
        for j in range(no_of_video):
            
            fname1 = "C:\\Users\\KIIT\\Downloads\\Flip learning pedagogy DTW\\DataSet\\DataSet_three_second\\S"+str(i)+"_3\\s"+format(i,'02d')+"_video"+str(j)+".csv"
            print(fname1)
            df = pd.read_csv(fname1)
#             df=df1['RAW']
            #print(type(df))
#             x = df.values.tolist()
#             list_f.append(x)
#             #df.values
#             print(len(x))
#             n = 1024
  
#             # using list comprehension 
#             final = [x[i * n:(i + 1) * n] for i in range((len(x) + n - 1) // n )]  
#             print (len(final))
#             final = final[:-1]
            df = df.iloc[:, :512]
            np.savetxt(fname1, df, delimiter=",")
# Out:
# ............................. 1
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_three_second\S1_3\s01_video0.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_three_second\S1_3\s01_video1.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_three_second\S1_3\s01_video2.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_three_second\S1_3\s01_video3.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_three_second\S1_3\s01_video4.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_three_second\S1_3\s01_video5.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_three_second\S1_3\s01_video6.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_three_second\S1_3\s01_video7.csv
# C:\Users\KIIT\Downloads\Flip learning pedagogy DTW\DataSet\DataSet_three_second\S1_3\s01_video8.csv
# ...
